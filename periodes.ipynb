# %%
import pandas as pd
import re
donnees = pd.read_csv("festivals_sites1.csv", sep=";")
donnees.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Unnamed: 1                       Nom du festival  \
# 0             0         0.0         0.0                         Le Grand HUIT
# 1             1         1.0         1.0                     La Clé des Portes
# 2             2         2.0         2.0                          Kreyolfiesta
# 3             3         3.0         3.0  Cinestar International Film Festival
# 4             4         4.0         4.0                             FestiLoir
#
#                               Envergure territoriale  \
# 0                                                NaN
# 1                                          Régionale
# 2  À l'échelle de l'arc antillais et/ou de la Guyane
# 3  À l'échelle de l'arc antillais et/ou de la Guyane
# 4                                     Intercommunale
#
#   Région principale de déroulement Département principal de déroulement  \
# 0                 Pays de la Loire                     Loire-Atlantique
# 1              Centre-Val de Loire                         Loir-et-Cher
# 2                       Martinique                           Martinique
# 3                       Guadeloupe                           Guadeloupe
# 4                 Pays de la Loire                               Sarthe
#
#   Commune principale de déroulement  \
# 0                            Nantes
# 1                             Talcy
# 2                    Fort-de-France
# 3                        Les Abymes
# 4                              Vaas
#
#   Code postal (de la commune principale de déroulement) Code Insee commune  \
# 0                                              44000                 44109
# 1                                              41370                 41253
# 2                                              97200                 97209
# 3                                              97139                 97101
# 4                                              72500                 72364
#
#    ...                             Sous-catégorie musique  \
# 0  ...                                                NaN
# 1  ...  Musique classique, jazz, gospel et compositeur...
# 2  ...                                                NaN
# 3  ...  Court métrage, Documentaire, Fiction long métr...
# 4  ...                                                NaN
#
#                           Sous-catégorie Musique CNM  \
# 0                                                NaN
# 1  11- Musique classique, lyrique, contemporaine,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sous-catégorie cinéma et audiovisuel  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   Sous-catégorie arts visuels et arts numériques  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#      Sous-catégorie livre et littérature  \
# 0                                    NaN
# 1                                    NaN
# 2  Festival des cultures du monde créole
# 3                                    NaN
# 4                                    NaN
#
#   Période principale de déroulement du festival Identifiant Agence A  \
# 0      Après-saison (6 septembre - 31 décembre)                  NaN
# 1                Saison (21 juin - 5 septembre)                  NaN
# 2                                      Décembre                  NaN
# 3      Après-saison (6 septembre - 31 décembre)                  NaN
# 4                Saison (21 juin - 5 septembre)                  NaN
#
#        Identifiant                   Géocodage xy identifiant CNM
# 0  FEST_44109_4303  47.2316356767, -1.54831008605             NaN
# 1  FEST_41253_6498    47.7683772018, 1.4383898244          5892.0
# 2  FEST_97209_2287  14.6411114389, -61.0691889244             NaN
# 3  FEST_97101_3232  16.2727794035, -61.5017044974             NaN
# 4  FEST_72364_6837  47.6723014522, 0.315373744758             NaN
#
# [5 rows x 33 columns]

# %%
def periodiser (x):
        x = str(x)
        if re.match(r".*[j,J]anvier.*", str(x)) or re.match(r".*[f,F].vrier.*", str(x)) or re.match(r".*[m,M]ars.*",str(x)) or re.match(r".*vril.*",str(x)) or re.match(r".*[m,M]ai.*", str(x)) or re.match(r"[J,j]uin", str(x)) or x=="Avant-saison (1er janvier - 20 juin)":
           return "Avant-saison (1er janvier - 20 juin)"
        elif re.match(r".*[j,J]uillet.*",str(x)) or re.match(r".*[a,A]o.t.*",str(x)) or x=="Saison (21 juin - 5 septembre)":
            return "Saison (21 juin - 5 septembre)"
        elif re.match(r"[S,s]eptembre",x) or re.match(r".*ctobre.*",str(x)) or re.match(r".*[n,N]ovembre.*",str(x)) or re.match(r".*[d,D].cembre.*", str(x)) or x=="Après-saison (6 septembre - 31 décembre)":
            return "Après-saison (6 septembre - 31 décembre)"
        elif x == "nan":
            pass
        else:
            return f"000 erreur {x}"

periodiser("Après - saison (6 septembre , 31 décembre)")

# mois = ["janvier", "février", "mars"]
# def period(x):
#      x = str(x)
#     match < <    in mois:
#         case "janvier" in x.lower()

# period("prout janvier")
# Out:
# 'Après-saison (6 septembre - 31 décembre)'

# %%
donnees['Période principale de déroulement du festival']= donnees['Période principale de déroulement du festival'].apply(periodiser)
donnees['Période principale de déroulement du festival']
# Out:
# 0       Après-saison (6 septembre - 31 décembre)
# 1                 Saison (21 juin - 5 septembre)
# 2       Après-saison (6 septembre - 31 décembre)
# 3       Après-saison (6 septembre - 31 décembre)
# 4                 Saison (21 juin - 5 septembre)
#                           ...
# 7282              Saison (21 juin - 5 septembre)
# 7283                                        None
# 7284                                        None
# 7285                                        None
# 7286                                        None
# Name: Période principale de déroulement du festival, Length: 7287, dtype: object

# %%
donnees.to_csv("festivals_periodes.csv", sep=";")
