# %%
import pandas as pd

donnees = pd.read_csv("festivals.csv", sep=";")
donnees.head()
# Out:
#                         Nom du festival  \
# 0                         Le Grand HUIT
# 1                     La Clé des Portes
# 2                          Kreyolfiesta
# 3  Cinestar International Film Festival
# 4                             FestiLoir
#
#                               Envergure territoriale  \
# 0                                                  /
# 1                  28 % public origine Ile de France
# 2  À l'échelle de l'arc antillais et/ou de la Guyane
# 3  À l'échelle de l'arc antillais et/ou de la Guyane
# 4  à l'échelle du Pays Vallée du Loir (57 commune...
#
#   Région principale de déroulement Département principal de déroulement  \
# 0                 Pays de la Loire                     Loire-Atlantique
# 1              Centre-Val de Loire                         Loir-et-Cher
# 2                       Martinique                           Martinique
# 3                       Guadeloupe                           Guadeloupe
# 4                 Pays de la Loire                               Sarthe
#
#   Commune principale de déroulement  \
# 0                            Nantes
# 1                             Talcy
# 2                    Fort-de-France
# 3                        Les Abymes
# 4                              Vaas
#
#   Code postal (de la commune principale de déroulement) Code Insee commune  \
# 0                                              44000                 44109
# 1                                              41370                 41253
# 2                                              97200                 97209
# 3                                              97139                 97101
# 4                                              72500                 72364
#
#   Code Insee EPCI                   Libellé EPCI Numéro de voie  ...  \
# 0       244400404               Nantes Métropole              9  ...
# 1       200055481         CC Beauce Val de Loire             18  ...
# 2       249720061  CA du Centre de la Martinique              2  ...
# 3       200018653              CA Cap Excellence            NaN  ...
# 4       200073112                  CC Sud Sarthe              1  ...
#
#                               Sous-catégorie musique  \
# 0                                                NaN
# 1  Musique classique, jazz, gospel et compositeur...
# 2                                                NaN
# 3  Court métrage, Documentaire, Fiction long métr...
# 4                                                NaN
#
#                           Sous-catégorie Musique CNM  \
# 0                                                NaN
# 1  11- Musique classique, lyrique, contemporaine,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sous-catégorie cinéma et audiovisuel  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   Sous-catégorie arts visuels et arts numériques  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#      Sous-catégorie livre et littérature  \
# 0                                    NaN
# 1                                    NaN
# 2  Festival des cultures du monde créole
# 3                                    NaN
# 4                                    NaN
#
#   Période principale de déroulement du festival Identifiant Agence A  \
# 0      Après-saison (6 septembre - 31 décembre)                  NaN
# 1                Saison (21 juin - 5 septembre)                  NaN
# 2                                      Décembre                  NaN
# 3      Après-saison (6 septembre - 31 décembre)                  NaN
# 4                Saison (21 juin - 5 septembre)                  NaN
#
#        Identifiant                   Géocodage xy identifiant CNM
# 0  FEST_44109_4303  47.2316356767, -1.54831008605             NaN
# 1  FEST_41253_6498    47.7683772018, 1.4383898244          5892.0
# 2  FEST_97209_2287  14.6411114389, -61.0691889244             NaN
# 3  FEST_97101_3232  16.2727794035, -61.5017044974             NaN
# 4  FEST_72364_6837  47.6723014522, 0.315373744758             NaN
#
# [5 rows x 30 columns]

# %%
import re
def departemental(x):
    try:
        if re.match(r'.*interr.egional.*',x.lower()):
            return "Interregionale"
        elif re.match(r'.*transfrontali.*',x.lower()):
            return "Transfrontalière"
        elif re.match(r'.*intercommun',x.lower()) or re.match(r".*communes.*",x.lower()):
            return "Intercommunale"
        elif re.match(r".*d.partemental.*", x.lower()):
            return "Départementale"
        elif re.match(r".*r.gional.*",x.lower()):
            return "Régionale"
        elif re.match(r"international.*", x.lower()):
            return "Internationale"
        elif re.match(r".*communale.*", x.lower()) or re.match(r".*ville.*",x.lower()) or re.match(r'.*commune.*',x.lower()) or re.match(r'.*unicipal.*',x.lower()):
            return "Communale"
        else:
            return x
    except:
        pass

# %%
envergure=donnees['Envergure territoriale']
envergure
# Out:
# 0                                                       /
# 1                       28 % public origine Ile de France
# 2       À l'échelle de l'arc antillais et/ou de la Guyane
# 3       À l'échelle de l'arc antillais et/ou de la Guyane
# 4       à l'échelle du Pays Vallée du Loir (57 commune...
#                               ...
# 7278                                                  NaN
# 7279                                                  NaN
# 7280                                                  NaN
# 7281                                                  NaN
# 7282                                                  NaN
# Name: Envergure territoriale, Length: 7283, dtype: object

# %%
donnees['Envergure territoriale']=donnees['Envergure territoriale'].apply(departemental)

# %%
donnees.to_csv("festivals_departements.csv", sep=";")
