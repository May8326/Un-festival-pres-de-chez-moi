# %%
import pandas as pd
donnees = pd.read_csv("festivals_departements.csv", sep=";")
donnees.head()
# Out:
#    Unnamed: 0                       Nom du festival  \
# 0           0                         Le Grand HUIT
# 1           1                     La Clé des Portes
# 2           2                          Kreyolfiesta
# 3           3  Cinestar International Film Festival
# 4           4                             FestiLoir
#
#                               Envergure territoriale  \
# 0                                                  /
# 1                  28 % public origine Ile de France
# 2  À l'échelle de l'arc antillais et/ou de la Guyane
# 3  À l'échelle de l'arc antillais et/ou de la Guyane
# 4                                     Intercommunale
#
#   Région principale de déroulement Département principal de déroulement  \
# 0                 Pays de la Loire                     Loire-Atlantique
# 1              Centre-Val de Loire                         Loir-et-Cher
# 2                       Martinique                           Martinique
# ...

# %%
def adressemail(x):
    listemail = str(x).split('@')
    if len(listemail) >1 :
        return x
    else :
        return "Non renseignée"
    

adressemail("fantinpro84@gmail.com")
# Out:
# 'fantinpro84@gmail.com'

# %%
donnees['Adresse e-mail']=donnees['Adresse e-mail'].apply(adressemail)

# %%
donnees.to_csv("festivals_adressemail.csv", sep=";")
